# %% [markdown]
# ## Observations and Insights
# - There is only one outlier in the dataset, which means that this dataset is very consistent and reliable.
# - Most mice are being treated with the drug Capomulin (230) and the least amount of mice (182) are being treated with Zoniferol
# - The correlation between mouse weight, and average tumor volume is 0.84. It is a strong positive correlation, when the mouse weight increases the average tumor volume also increases.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)
print(mouse_metadata.columns)
print(study_results.columns)
# Combine the data into a single dataset
mouse_results = pd.merge(mouse_metadata, study_results, on='Mouse ID', how='right')
# Display the data table for preview
mouse_results
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)'], dtype='object')
# Index(['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'], dtype='object')
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        b128    Capomulin  Female           9          22          0
# 1        b128    Capomulin  Female           9          22          5
# 2        b128    Capomulin  Female           9          22         10
# 3        b128    Capomulin  Female           9          22         15
# 4        b128    Capomulin  Female           9          22         20
# ...       ...          ...     ...         ...         ...        ...
# 1888     m601    Capomulin    Male          22          17         25
# 1889     m601    Capomulin    Male          22          17         30
# 1890     m601    Capomulin    Male          22          17         35
# 1891     m601    Capomulin    Male          22          17         40
# ...

# %%
# Checking the number of mice.
mice_number = mouse_results["Mouse ID"].count()
unique_mice_number = mouse_results["Mouse ID"].nunique()
print(f"Total number of mice is", mice_number)
print(f"Total number of unique mice is",unique_mice_number)
# Out:
# Total number of mice is 1893
# Total number of unique mice is 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse = mouse_results[mouse_results.duplicated(["Mouse ID","Timepoint"])]
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 861     g989     Propriva  Female          21          26          0
# 863     g989     Propriva  Female          21          26          5
# 865     g989     Propriva  Female          21          26         10
# 867     g989     Propriva  Female          21          26         15
# 869     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 861           45.000000                 0
# 863           47.570392                 0
# 865           49.880528                 0
# 867           53.442020                 0
# 869           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all_duplicate_mouse = mouse_results.loc[mouse_results["Mouse ID"] == 'g989']
all_duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 860     g989     Propriva  Female          21          26          0
# 861     g989     Propriva  Female          21          26          0
# 862     g989     Propriva  Female          21          26          5
# 863     g989     Propriva  Female          21          26          5
# 864     g989     Propriva  Female          21          26         10
# 865     g989     Propriva  Female          21          26         10
# 866     g989     Propriva  Female          21          26         15
# 867     g989     Propriva  Female          21          26         15
# 868     g989     Propriva  Female          21          26         20
# 869     g989     Propriva  Female          21          26         20
# 870     g989     Propriva  Female          21          26         25
# 871     g989     Propriva  Female          21          26         30
# 872     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_results = mouse_results.drop_duplicates(subset=["Mouse ID","Timepoint"])
clean_results.loc[clean_results["Mouse ID"] == 'g989']
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 860     g989     Propriva  Female          21          26          0
# 862     g989     Propriva  Female          21          26          5
# 864     g989     Propriva  Female          21          26         10
# 866     g989     Propriva  Female          21          26         15
# 868     g989     Propriva  Female          21          26         20
# 870     g989     Propriva  Female          21          26         25
# 871     g989     Propriva  Female          21          26         30
# 872     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 860           45.000000                 0
# 862           48.786801                 0
# 864           51.745156                 0
# 866           51.325852                 1
# 868           55.326122                 1
# 870           56.045564                 1
# 871           59.082294                 1
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice_number = clean_results["Mouse ID"].count()
c_unique_mice_number = clean_results["Mouse ID"].nunique()
print(f"Total number of mice is", clean_mice_number)
print(f"Total number of unique mice is",c_unique_mice_number)
# Out:
# Total number of mice is 1888
# Total number of unique mice is 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
summary_df = clean_results.groupby("Drug Regimen")
# mean, median, variance, standard deviation, and SEM of the tumor volume.
tumor_mean = summary_df["Tumor Volume (mm3)"].mean()
tumor_median = summary_df["Tumor Volume (mm3)"].median()
tumor_variance = summary_df["Tumor Volume (mm3)"].var()
tumor_stdev = summary_df["Tumor Volume (mm3)"].std()
tumor_sem = summary_df["Tumor Volume (mm3)"].sem()
# Assemble the resulting series into a single summary dataframe.
summary_table_df = pd.DataFrame({'Mean': tumor_mean, 'Median': tumor_median,
                                   'Variance': tumor_variance, 'Standard Deviation': tumor_stdev, 'SEM': tumor_sem})
summary_table_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
agg_df = summary_df["Tumor Volume (mm3)"].agg(['mean','median','var','std','sem'])
agg_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
drug_groups = clean_results.groupby("Drug Regimen")
mea_counts = pd.DataFrame(drug_groups['Drug Regimen'].count())
bar_plot = mea_counts.plot(kind='bar', title='Number of Measurements for each Drug Regimen', color='blue', figsize=(6.5,5))
# Set x and y labels
bar_plot.set_xlabel('Drug Regimen')
bar_plot.set_ylabel('Number of Measurements')
plt.tight_layout()
# Save figure
plt.savefig("Images/PandasBarChart.png")
plt.show()
mea_counts
# Out:
#               Drug Regimen
# Drug Regimen
# Capomulin              230
# Ceftamin               178
# Infubinol              178
# Ketapril               188
# Naftisol               186
# Placebo                181
# Propriva               156
# Ramicane               228
# Stelasyn               181
# Zoniferol              182

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
x_axis = np.arange(len(mea_counts))
tick_locations = [value for value in x_axis]

plt.bar(x_axis, mea_counts["Drug Regimen"], color='blue', align="center", width=0.50)
plt.xticks(tick_locations, list(mea_counts.index), rotation="vertical")
# Set x and y limits
plt.xlim(-0.5, len(x_axis)-0.5)
plt.ylim(0, max(mea_counts["Drug Regimen"])*1.05)
# Set title and lablels
plt.title("Number of Measurements for each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")
# Set legend
column_name = ["Drug Regimen"]
plt.legend(column_name,loc="best")
plt.tight_layout()
# Save figure
plt.savefig("Images/PyplotBarChart.png")
plt.show()

# %%
# Create sex dataframe in order to generate a pie plot
# Total sex count
group_sex = clean_results.groupby("Sex")
group_sex_count = pd.DataFrame(group_sex["Sex"].count())
group_sex_count = group_sex_count.rename(columns={'Sex': 'Number of Mice'})
group_sex_count
# Out:
#         Number of Mice
# Sex
# Female             930
# Male               958

# %%
# Sex count for unique Mouse ID
u_group_sex = clean_results.groupby("Sex")
u_group_sex_count = pd.DataFrame(u_group_sex["Mouse ID"].nunique())
u_group_sex_count = u_group_sex_count.rename(columns={'Mouse ID': 'Number of Mice'})
u_group_sex_count.head()
# Out:
#         Number of Mice
# Sex
# Female             124
# Male               125

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
group_sex_count.plot(kind='pie', y='Number of Mice', title='Distribution of female vs male mice',
                     autopct='%1.1f%%', fontsize=14, shadow=True, colors=['red','blue'],
                     startangle=120, legend=False)
plt.axis('equal')
# Save figure
plt.savefig("Images/PyplotPieChart.png")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
genders = ['Female', 'Male']

# The values of each section of the pie chart
gender_counts = group_sex_count['Number of Mice']

# The colors of each section of the pie chart
colors = ["red", "blue"]

# Creates the pie chart based upon the values above
plt.pie(gender_counts, labels=genders, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=120)
plt.rcParams['font.size'] = 14
plt.title("Distribution of female versus male mice")
plt.ylabel("Sex")
plt.axis("equal")
# Save figure
plt.savefig("Images/PyplotPieChart.png")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_tp_df = pd.DataFrame(clean_results.groupby('Mouse ID')['Timepoint'].max().sort_values()).reset_index().rename(columns={'Timepoint': 'Max Timepoint'})
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_df = pd.merge(clean_results, max_tp_df, on='Mouse ID')
merged_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     b128    Capomulin  Female           9          22          0
# 1     b128    Capomulin  Female           9          22          5
# 2     b128    Capomulin  Female           9          22         10
# 3     b128    Capomulin  Female           9          22         15
# 4     b128    Capomulin  Female           9          22         20
#
#    Tumor Volume (mm3)  Metastatic Sites  Max Timepoint
# 0           45.000000                 0             45
# 1           45.651331                 0             45
# 2           43.270852                 0             45
# 3           43.784893                 0             45
# 4           42.731552                 0             45

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
# Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    
    drug_df = merged_df.loc[merged_df['Drug Regimen'] == treatment]
    
# add subset 
    final_volume_df = drug_df.loc[drug_df['Timepoint'] == drug_df['Max Timepoint']]
    values = final_volume_df['Tumor Volume (mm3)']
    tumor_vol.append(values)
    
# Determine outliers using upper and lower bounds
    quartiles = values.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {treatment}: {iqr}')
    
# Find upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {treatment}: {lower_bound}')
    print(f'Upper Bound for {treatment}: {upper_bound}')
    
# Quantitatively check for outliers
    outliers_count = (values.loc[(final_volume_df['Tumor Volume (mm3)'] > upper_bound) | 
                                        (final_volume_df['Tumor Volume (mm3)'] < lower_bound)]).count()
    print(f'Number of {treatment} outliers: {outliers_count}''\n')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
#
# IQR for Ramicane: 9.098536719999998
# Lower Bound for Ramicane: 17.912664470000003
# Upper Bound for Ramicane: 54.30681135
# Number of Ramicane outliers: 0
#
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
#
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
flierprops = dict(marker='o', markerfacecolor='red', markersize=9)
plt.boxplot(tumor_vol, flierprops=flierprops)
# Set title,x and y labels, and ticker names
plt.title('Final Tumor Volume by Drug')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.tight_layout()
# Save figure
plt.savefig("Images/BoxPlot.png")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse = clean_results.loc[clean_results["Mouse ID"]== 'b128']
plt.plot(mouse['Timepoint'],mouse['Tumor Volume (mm3)'], marker='s')
# Add title, x and y labels
plt.xlabel("Time")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment of Mouse b128")
plt.tight_layout()
# Save figure
plt.savefig("Images/MouseLinePlot.png")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin = clean_results.loc[clean_results["Drug Regimen"]=='Capomulin']
avg_vol = pd.DataFrame(capomulin.groupby('Mouse ID')['Tumor Volume (mm3)']\
                       .mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Tumor Volume (mm3)'})
avg_vol = pd.merge(capomulin, avg_vol, on='Mouse ID')
clean_avg_vol = avg_vol[["Weight (g)", "Average Tumor Volume (mm3)"]].drop_duplicates()

x = clean_avg_vol['Weight (g)']
y = clean_avg_vol['Average Tumor Volume (mm3)']

plt.scatter(x,y)
# Add title, x and y labels
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume vs Weight")
plt.tight_layout()
# Save figure
plt.savefig("Images/ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(x,y)
print(f'The correlation between Weight and Average Tumor Volume\
on the Capomulin regimen is {round(correlation[0],2)}.')

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="red")
# Add title, x and y labels
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume vs Weight")
plt.tight_layout()
# Save figure
plt.savefig("Images/ScatterPlotRegression.png")
plt.show()
# Out:
# The correlation between Weight and Average Tumor Volumeon the Capomulin regimen is 0.84.
# The r-squared is: 0.7088568047708717
